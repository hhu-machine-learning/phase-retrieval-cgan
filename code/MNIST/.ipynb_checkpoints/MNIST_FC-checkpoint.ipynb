# %%
### Prepare module structure ###

import sys
sys.path.append("../")

# %%
### IMPORT ###

import numpy as np
import math
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim

import time

import matplotlib.pyplot as plt
# %matplotlib inline

from util import *
import data
import models

# auto reload imports on local changes
# %load_ext autoreload
# %autoreload 2
print(torch.__version__)
# Out:
# 1.0.0

# %%
### Check device ###

USE_GPU = True

dtype = torch.float32

if USE_GPU and torch.cuda.is_available():
    # TODO: Change to CPU used!
    device = torch.device('cuda:1')
else:
    device = torch.device('cpu')

print('using device:', device)
# Out:
# using device: cuda:1

# %%
### LOAD DATA ###

dataset = 'mnist'
dataloader, imsize = data.load(dataset, path='/home/shared/phase-retrieval/data/' + dataset, batch_size=32)

sample = next(iter(dataloader['train']))
sample_ft =  torch.rfft(sample, 2, onesided=False)
sample_magnitudes = torch.sqrt(torch.sum(sample_ft ** 2, -1))

plot_grid(sample)
print(sample_magnitudes.shape)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([32, 1, 28, 28])

# %%
def calc_mags(x):
    ft =  torch.rfft(x, 2, onesided=False)
    mags = torch.sqrt(torch.sum(ft ** 2, -1) + 1e-16)
    return mags


def test_generator(model, device, testloader, one_batch=False):
    # put model to eval mode
    model = model.to(device=device)
    model.eval()

    # move test images to device and reduce to magnitude information in fourier space
    test_images = []
    outputs = []
    
    for data in testloader:
        data = data.to(device=device)
        real_magn = calc_mags(data)
        ouput = model(real_magn)

        test_images.append(data.cpu().numpy())
        outputs.append(ouput.cpu().detach().numpy())
        if one_batch: break
    
    return np.concatenate(test_images), np.concatenate(outputs)

# %%
# Define loss

def gen_loss(gen_output, x):
    return  torch.mean(torch.abs(gen_output - x))

# %%
### Create new models ###

gen = models.FCNet(imsize=imsize, h=2048)
# Out:
# Version 0.4

# %%
# Set training parameters

history = []
opt = optim.Adam(gen.parameters(), lr=1e-3)

# %%
# Initial loss

gen = gen.to(device)
sample = sample.to(device)
sample_magnitudes = sample_magnitudes.to(device)

gen_out = gen(sample_magnitudes)

loss = gen_loss(gen_out, sample)

print("Generator loss:", loss.item())
# Out:
# Generator loss: 0.4712563753128052

# %%
def train_model(gen, opt, device, loader_train, epochs=1):
    """
    Train a the conditional gan
    
    Returns: Loss history per iteration step
    """
    
    # move the model parameters to CPU/GPU
    gen = gen.to(device=device)
    
    # loss history
    history = []
    
    for e in range(epochs):
        for t, (x) in enumerate(loader_train):
            # put model to training mode
            gen.train()
            
            # move x to device and reduce to magnitude information in fourier space
            x = x.to(device=device)
            magnitudes = calc_mags(x)
            
            # calculate loss and update generator
            loss = gen_loss(gen(magnitudes), x)
            opt.zero_grad()
            loss.backward()
            opt.step()
            
            history.append(loss.item())

            if t % 100 == 0:
                print("epoch: {:2} \t step:{} \t loss: {:3.4}".format(e+1, t, history[-1]))  
            
        plt.plot(history)
        plt.show()
        
        test_images, test_outputs = test_generator(gen, device, dataloader['val'])

        plot_grid(np.vstack([test_images[:16],test_outputs[:16], test_images[16:32], test_outputs[16:32]]), figsize=(8,8))
        
        mse_val = np.mean((test_outputs - test_images)**2)
        print("Mean squared dist:", mse_val)
        
        torch.save(gen.state_dict().copy(), "../cache/FCNet2048MNIST_{0:04d}_{1}_{2:.3f}.sd".format(e+1, time.strftime("%Y%m%d_%H%M%S"), mse_val))
  
    return history

# %%
### TRAIN MODEL ###

import time
num_epochs = 100

train_model(gen, opt, device, dataloader['train'], epochs=num_epochs)

gen_weights = gen.state_dict().copy()

torch.save(gen_weights, "../cache/FC/FCNet2048MNIST_{0:04d}_{1}.sd".format(num_epochs, time.strftime("%Y%m%d_%H%M%S")))
# Out:
# epoch:  1 	 step:0 	 loss: 0.4719
# epoch:  1 	 step:100 	 loss: 0.09226
# epoch:  1 	 step:200 	 loss: 0.0875
# epoch:  1 	 step:300 	 loss: 0.08059
# epoch:  1 	 step:400 	 loss: 0.08054
# epoch:  1 	 step:500 	 loss: 0.078
# epoch:  1 	 step:600 	 loss: 0.07492

# %%
### LOAD MODEL ####

gen = models.FCNet(imsize=imsize, h=2048)

# TODO: map storage location to correct GPU!
gen.load_state_dict(torch.load("../cache/FC/FCNet2048MNIST_0100_20190907_181457.sd", map_location={'cuda:1': device.__str__()}));
gen.eval();
# Out:
# Version 0.4

# %%
# Calculate test predictions #

test_original, test_predicted = test_generator(gen, device, dataloader['test'])
print(test_predicted.shape)
# Out:
# (8000, 1, 28, 28)

# %%
### CACHE RESULTS ###

import pickle
pickle.dump(test_original, open("/home/shared/phase-retrieval/test/FCnet_MNIST/original_6.p", "wb"))
pickle.dump(test_predicted, open("/home/shared/phase-retrieval/test/FCnet_MNIST/predicted_6.p", "wb"))

# %%
### LOAD RESULTS ###
import pickle

test_original = pickle.load(open("/home/shared/phase-retrieval/test/FCnet_MNIST/original_6.p", "rb"))
test_predicted = pickle.load(open("/home/shared/phase-retrieval/test/FCnet_MNIST/predicted_6.p", "rb"))

# %%
# Benchmark test predictions #

benchmark(pred=test_predicted[:1024], true=test_original[:1024], check_all=True)
# Out:
# Signal error:
#   MSE: 0.024438006578975546, std: 0.0180533153354052
#   MAE: 0.04858221923950623, std: 0.02469868901204814
#   SSIM: 0.7938195780644008, std: 0.1360230228558207
#   FASI-MSE: 0.020173180981601035, std: 0.013708592438474321
#   FASI-MAE: 0.04324297540188127, std: 0.019743868978206493
#   COCO-MSE: 0.018369209577515415, std: 0.01013020989040197
#
# Magnitude error:
#   MSE Magnitude: 4.388224112439889, std: 3.118465472139975
#
# Image constraints:
#   Imag part = 0.0 - should be very close to 0
#   Real part is in [0.00, 1.00] - should be in [0, 1]

# %%
# Print test predictions 2 #
to_plot = np.stack([test_original[:32, 0].reshape(4, 8, 28, 28), 
                    test_predicted[:32, 0].reshape(4, 8, 28, 28)], axis=1).reshape(-1, 1, 28, 28)
 
                
plot_grid(to_plot, figsize=(8,8), file="../out/e2e/mnist/FCNet2048MNIST_6.png")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Evaluation for different FC  (1024 samples)
#
# | Nr | Loss | Size | epochs | Val MSE | MSE | MAE | SSIM | FASI-MSE | FASI-MAE | COCO-MSE | MSE Magn
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 1 | MAE | 2048 | 10 | 0.0240 | 0.02724 | 0.05064 | 0.7781 | 0.02384 | 0.04644 | 0.02146 | 5.371
# | 2 | MAE | 2048 | 20 | 0.0240 | 0.02549 | 0.04846 | 0.7927 | 0.02121 | 0.04319 | 0.01959 | 4.655
# | 3 | MAE | 2048 | 30 | 0.0234 | 0.02521 | 0.04863 | 0.7918 | 0.02080 | 0.04314 | 0.01937 | 4.693
# | 4 | MAE | 2048 | 40 | 0.0234 | 0.02504 | 0.04842 | 0.7949 | 0.02076 | 0.04312 | 0.01917 | 4.628
# | 5 | MAE | 2048 | 50 | 0.0233 | 0.02483 | 0.04829 | 0.7939 | 0.02018 | 0.04255 | 0.01880 | 4.575
# | 6 | MAE | 2048 | 100 | 0.0225 | 0.02444 | 0.04858 | 0.7938 | __0.02017__ | 0.04324 | __0.01836__ | 4.388

# %%
### Exchange original phase with FC Net computed phase ###

orig_fft = np.fft.fft2(test_original[:1024])
orig_magn = np.abs(orig_fft)
orig_phase = np.angle(orig_fft)
test_fft = np.fft.fft2(test_predicted[:1024])
test_magn = np.abs(test_fft)
test_Phase = np.angle(test_fft)

Combined = orig_magn * np.exp(1j * test_Phase)
combined = np.fft.ifft2(Combined)

# %%
# Benchmark predicted phase with original magnitude #

benchmark(pred=combined, true=test_original[:1024], check_all=True)
# Out:
# Signal error:
#   MSE: 0.024022872012988764, std: 0.021466244828315995
#   MAE: 0.08050262601206534, std: 0.0354681963697031
# /home/alobe101/.local/lib/python3.6/site-packages/skimage/measure/_structural_similarity.py:155: UserWarning: Inputs have mismatched dtype.  Setting data_range based on X.dtype.
#   warn("Inputs have mismatched dtype.  Setting data_range based on "
#   SSIM: 0.7117804375550237, std: 0.15633416294868252
#   FASI-MSE: 0.018825470032935138, std: 0.015246340975116266
#   FASI-MAE: 0.074307603694624, std: 0.030416088862306026
#   COCO-MSE: 0.016734729163175237, std: 0.011018136439725858
#
# Magnitude error:
#   MSE Magnitude: 4.643619739024233e-30, std: 1.713337521222949e-30
#
# Image constraints:
#   Imag part = -6.1526378366221905e-24 - should be very close to 0
#   Real part is in [-0.55, 1.74] - should be in [0, 1]

# %%
# Print test predictions 2 #
to_plot = np.stack([test_original[:32, 0].reshape(4, 8, 28, 28), 
                    np.real(combined)[:32, 0].reshape(4, 8, 28, 28)], axis=1).reshape(-1, 1, 28, 28)
 
                
plot_grid(to_plot, figsize=(8,8), file="../out/e2e/mnist/FCNet2048MNIST_6_origMagn.png")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Evaluation for different FC models with original magnitudes (first 1024 test samples)
#
# | Nr | Loss | Size | epochs | MSE | MAE | SSIM | FASI-MSE | FASI-MAE | COCO-MSE | MSE Magn | \[min,max\]
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | 1 | MAE | 2048 | 10 | 0.02591 | 0.08621 | 0.6859 | 0.02173 | 0.08115 | 0.01894 | ~0 | \[-0.64, 1.91\]
# | 2 | MAE | 2048 | 20 | 0.02386 | 0.08105 | 0.7090 | 0.01894 | 0.07511 | 0.01707 | ~0 | \[-0.53, 1.91\]
# | 3 | MAE | 2048 | 30 | 0.02398 | 0.08152 | 0.7061 | 0.01865 | 0.07504 | 0.01702 | ~0 | \[-0.49, 1.88\]
# | 4 | MAE | 2048 | 40 | 0.02369 | 0.08097 | 0.7085 | 0.01854 | 0.07473 | 0.01677 | ~0 | \[-0.47, 1.58\]
# | 5 | MAE | 2048 | 50 | 0.02392 | 0.08076 | 0.70982 | 0.01837 | 0.07412 | 0.01672 | ~0 | \[-0.52, 1.87\]
# | 6 | MAE | 2048 | 100 | 0.02402 | 0.08050 | 0.7118 | 0.01883 | 0.07431 | 0.01673 | ~0 | \[-0.55, 1.74\]
