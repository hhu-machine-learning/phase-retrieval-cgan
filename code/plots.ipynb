# %%
### IMPORT ###

import numpy as np
from util import *

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
steps = [1, 10, 25, 100, 500, 1000, 2000, 4000, 10000]

# %% [markdown]
# ## HIO MNIST
#
# | steps | restarts | MSE | MAE | SSIM | SHRP | PhCo-MSE | PhCo-MAE | PhCo-SSIM | CroCo-MSE | CroCo-MAE | CroCo-SSIM | MSE Magn |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 1 | 3 | 0.1137 | 0.2165 | 0.03438 | 0.1951 | 0.09426 | 0.1957 | 0.1165 | 0.07300 | 0.1715 | 0.2137 | 24.74 |
# | 10 | 3 | 0.1648 | 0.2458 | 0.03543 | 0.2035 | 0.07774 | 0.1670 | 0.3126 | 0.06061 | 0.1511 | 0.3766 | 6.564 |
# | 25 | 3 | 0.1675 | 0.2336 | 0.06560 | 0.1842 | 0.06881 | 0.1422 | 0.4023 | 0.05413 | 0.1284 | 0.4588 | 3.331 |
# | 100 | 3 | 0.1695 | 0.2290 | 0.07621 | 0.1681 | 0.06182 | 0.1265 | 0.4655 | 0.04852 | 0.1140 | 0.5169 | 2.119 |
# | 500 | 3 | 0.1697 | 0.2253 | 0.08601 | 0.1543 | 0.05583 | 0.1147 | 0.5163 | 0.04494 | 0.1043 | 0.5596 | 1.586 |
# | 1000 | 3 | 0.1701 | 0.2250 | 0.08766 | 0.1522 | 0.05536 | 0.1128 | 0.5245 | 0.04443 | 0.1025 | 0.5680 | 1.500 |
# | 2000 | 3 | 0.1698 | 0.2243 | 0.08954 | 0.1516 | 0.05599 | 0.1130 | 0.5243 | 0.04445 | 0.1021 | 0.5683 | 1.466 |
# | 4000 | 3 | 0.1705 | 0.2249 | 0.08832 | 0.1505 | 0.05508 | 0.1115 | 0.5306 | 0.04407 | 0.1012 | 0.5723 | 1.432 |
# | 10000 | 3 | 0.1698 | 0.2242 | 0.08914 | 0.1499 | 0.05386 | 0.1104 | 0.5345 | 0.04404 | 0.1011 | 0.5727 | 1.446 |

# %%
hio_crocomse = [0.07300, 0.06061, 0.05413, 0.04852, 0.04494, 0.04443, 0.04445, 0.04407, 0.04404]

# %% [markdown]
# ## GS MNIST
#
# | steps | restarts | MSE | MAE | SSIM | SHRP | PhCo-MSE | PhCo-MAE | PhCo-SSIM | CroCo-MSE | CroCo-MAE | CroCo-SSIM | MSE Magn |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 1 | 3 | 0.1120 | 0.2064 | 0.04138 | 0.1835 | 0.09050 | 0.1816 | 0.1376 | 0.06945 | 0.1567 | 0.2384 | 24.58 |
# | 10 | 3 | 0.1650 | 0.2275 | 0.05673 | 0.1957 | 0.09490 | 0.1598 | 0.2842 | 0.06597 | 0.1312 | 0.3935 | 1.639 |
# | 25 | 3 | 0.1695 | 0.2228 | 0.07661 | 0.1850 | 0.08795 | 0.1459 | 0.3466 | 0.06238 | 0.1211 | 0.4416 | 0.7898 |
# | 100 | 3 | 0.1717 | 0.2173 | 0.1026 | 0.1700 | 0.07560 | 0.1270 | 0.4414 | 0.05639 | 0.1083 | 0.5174 | 0.2887 |
# | 500 | 3 | 0.1724 | 0.2145 | 0.1177 | 0.1566 | 0.06573 | 0.1128 | 0.5183 | 0.05056 | 0.09801 | 0.5798 | 0.1296 |
# | 1000 | 3 | 0.1723 | 0.2137 | 0.1213 | 0.1512 | 0.06216 | 0.1076 | 0.5438 | 0.04872 | 0.09467 | 0.6001 | 0.1050 |
# | 2000 | 3 | 0.1721 | 0.2131 | 0.1234 | 0.1472 | 0.06066 | 0.1050 | 0.5599 | 0.04726 | 0.09219 | 0.6145 | 0.09020 |
# | 4000 | 3 | 0.1720 | 0.2126 | 0.1250 | 0.1457 | 0.05845 | 0.1023 | 0.5718 | 0.04658 | 0.09087 | 0.6219 | 0.08125 |
# | 10000 | 3 | 0.1728 | 0.2131 | 0.1246 | 0.1450 | 0.05872 | 0.1023 | 0.5728 | 0.04639 | 0.09033 | 0.6250 | 0.07699 |
# | 10000 | 1 | 0.1736 | 0.2157 | 0.1116 | 0.1566 | 0.06635 | 0.1131 | 0.5167 | 0.05194 | 0.09938 | 0.5730 | 0.1330 |

# %%
gs_crocomse = [0.06945, 0.06597, 0.06238, 0.05639, 0.05056, 0.04872, 0.04726, 0.04658, 0.04639]

# %% [markdown]
# ## MNIST DPR
#
# | steps | lr | reg | MSE | MAE | SSIM | SHRP | PhCo-MSE | PhCo-MAE | PhCo-SSIM | CroCo-MSE | CroCo-MAE | CroCo-SSIM | MSE Magn |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 1 | 0.1 | - | 0.09886 | 0.1407 | 0.2474 | 0.1583 | 0.09521 | 0.1372 | 0.3293 | 0.07327 | 0.1135 | 0.4083 | 21.05 |
# | 10 | 0.1 | - | 0.09489 | 0.1327 | 0.3169 | 0.1435 | 0.07761 | 0.1139 | 0.4561 | 0.05676 | 0.09176 | 0.5358 | 9.883 |
# | 25 | 0.1 | - | 0.09244 | 0.1264 | 0.3618 | 0.1305 | 0.05817 | 0.08910 | 0.5772 | 0.04418 | 0.07428 | 0.6347 | 5.815 |
# | 100 | 0.1 | - | 0.08502 | 0.1169 | 0.4235 | 0.09851 | 0.03197 | 0.05683 | 0.7542 | 0.02557 | 0.05005 | 0.7813 | 2.232 |
# | 500 | 0.1 | - | 0.08395 | 0.1150 | 0.4414 | 0.06972 | 0.01748 | 0.03622 | 0.8619 | 0.01441 | 0.03299 | 0.8749 | 0.9564 |
# | 1000 | 0.1 | - | 0.08155 | 0.1121 | 0.4538 | 0.06250 | 0.01491 | 0.03185 | 0.8808 | 0.01236 | 0.02917 | 0.8916 | 0.7542 |
# | 2000 | 0.1 | - | 0.08608 | 0.1167 | 0.4311 | 0.05746 | 0.01389 | 0.02935 | 0.8912 | 0.01152 | 0.02684 | 0.9019 | 0.6409 |
# | 4000 | 0.1 | - | 0.08352 | 0.1138 | 0.4451 | 0.05111 | 0.01203 | 0.02608 | 0.9043 | 0.009754 | 0.02365 | 0.9145 | 0.5092 |
# | 10000 | 0.1 | - | 0.08567 | 0.1156 | 0.4383 | 0.04748 | 0.01184 | 0.02462 | 0.9095 | 0.009836 | 0.02257 | 0.9173 | 0.4648 |

# %%
vaeopt_crocomse = [0.07327, 0.05676, 0.04418, 0.02557, 0.01441, 0.01236, 0.01152, 0.009754, 0.009836]

# %% [markdown]
# ## MNIST PRCGAN*
#
# | steps | lr | reg | MSE | MAE | SSIM | SHRP | PhCo-MSE | PhCo-MAE | PhCo-SSIM | CroCo-MSE | CroCo-MAE | CroCo-SSIM | MSE Magn |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 1 | 0.1 | - | 0.02248 | 0.04585 | 0.8159 | 0.08312 | 0.01510 | 0.03677 | 0.8644 | 0.01367 | 0.03501 | 0.8744 | 2.426 |
# | 10 | 0.1 | - | 0.02064 | 0.04201 | 0.8359 | 0.06459 | 0.008601 | 0.02649 | 0.9185 | 0.007943 | 0.02567 | 0.9231 | 1.037 |
# | 25 | 0.1 | - | 0.01996 | 0.04010 | 0.8436 | 0.05315 | 0.005910 | 0.02125 | 0.9429 | 0.005443 | 0.02068 | 0.9463 | 0.5937 |
# | 100 | 0.1 | - | 0.02012 | 0.03797 | 0.8460 | 0.03455 | 0.002995 | 0.01350 | 0.9707 | 0.002712 | 0.01316 | 0.9730 | 0.2225 |
# | 500 | 0.1 | - | 0.02057 | 0.03642 | 0.8444 | 0.01956 | 0.001560 | 0.007792 | 0.9846 | 0.001353 | 0.007543 | 0.9862 | 0.07636 |
# | 1000 | 0.1 | - | 0.02072 | 0.03604 | 0.8438 | 0.01598 | 0.001328 | 0.006466 | 0.9869 | 0.001136 | 0.006245 | 0.9883 | 0.05313 |
# | 2000 | 0.1 | - | 0.02084 | 0.03578 | 0.8433 | 0.01334 | 0.001183 | 0.005510 | 0.9884 | 0.001013 | 0.005307 | 0.9897 | 0.04027 |
# | 4000 | 0.1 | - | 0.02093 | 0.03563 | 0.8428 | 0.01148 | 0.001055 | 0.004806 | 0.9894 | 0.0009179 | 0.004637 | 0.9905 | 0.03272 |
# | 10000 | 1.0 | - | 0.02102 | 0.03548 | 0.8423 | 0.009946 | 0.001011 | 0.004255 | 0.9898 | 0.0008475 | 0.004057 | 0.9911 | 0.02658 |

# %%
cganopt_crocomse = [0.01367, 0.007943, 0.005443, 0.002712, 0.001353, 0.001136, 0.001013, 0.0009179, 0.0008475]

# %%
axes = plt.gca()
axes.set_xlabel("Steps k")
#axes.set_xlabel("Mean SNR")
#axes.set_xlim([0, 50])
#plt.yticks(np.arange(0.0, 0.11, 0.01))
axes.set_xscale('log')
axes.set_ylabel("MSE (registered)")
axes.set_ylim([0, 0.08])
plt.title("")
plt.plot(steps, hio_crocomse, marker='.', label="HIO", color='C0')
plt.plot(steps, gs_crocomse, marker='.', label="GS", color='C4')
plt.plot(steps, vaeopt_crocomse, marker='.', label="DPR", color='C2')
plt.plot(steps, cganopt_crocomse, marker='.', label="PRCGAN* (ours)", color='C3')
plt.legend()
plt.grid()
plt.savefig("out/plots/MNIST_iterations.png", dpi=200)
plt.show()

# %% [markdown]
# ## Fashion HIO
#
# | steps | restarts | MSE | MAE | SSIM | SHRP | PhCo-MSE | PhCo-MAE | PhCo-SSIM | CroCo-MSE | CroCo-MAE | CroCo-SSIM | MSE Magn |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 1 | 3 | 0.1681 | 0.3119 | 0.04284 | 0.2017 | 0.1409 | 0.2787 | 0.1205 | 0.1011 | 0.2270 | 0.2306 | 46.12 |
# | 10 | 3 | 0.2141 | 0.3399 | 0.04547 | 0.2338 | 0.1315 | 0.2475 | 0.2289 | 0.06901 | 0.1776 | 0.3605 | 0.8981 |
# | 25 | 3 | 0.2158 | 0.3376 | 0.05292 | 0.2262 | 0.1270 | 0.2364 | 0.2639 | 0.06590 | 0.1674 | 0.3926 | 0.3104 |
# | 100 | 3 | 0.2159 | 0.3355 | 0.06075 | 0.2217 | 0.1261 | 0.2320 | 0.2866 | 0.06482 | 0.1629 | 0.4156 | 0.1093 |
# | 500 | 3 | 0.2212 | 0.3402 | 0.05944 | 0.2184 | 0.1245 | 0.2285 | 0.3056 | 0.06425 | 0.1603 | 0.4346 | 0.04436 |
# | 1000 | 3 | 0.2219 | 0.3405 | 0.06192 | 0.2177 | 0.1239 | 0.2273 | 0.3104 | 0.06414 | 0.1598 | 0.4385 | 0.03638 |
# | 2000 | 3 | 0.2219 | 0.3406 | 0.06074 | 0.2170 | 0.1241 | 0.2271 | 0.3133 | 0.06423 | 0.1596 | 0.4409 | 0.02940 |
# | 4000 | 3 | 0.2180 | 0.3359 | 0.06656 | 0.2166 | 0.1231 | 0.2257 | 0.3187 | 0.06408 | 0.1592 | 0.4434 | 0.02608 |
# | 10000 | 3 | 0.2191 | 0.3372 | 0.06630 | 0.2165 | 0.1233 | 0.2261 | 0.3171 | 0.06405 | 0.1591 | 0.4441 | 0.02512 |

# %%
hio_crocomse = [0.1011, 0.06901, 0.06590, 0.06482, 0.06425, 0.06414, 0.06423, 0.06408, 0.06405]

# %% [markdown]
# ## Fashion GS
#
# | steps | restarts | MSE | MAE | SSIM | SHRP | PhCo-MSE | PhCo-MAE | PhCo-SSIM | CroCo-MSE | CroCo-MAE | CroCo-SSIM | MSE Magn |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 1 | 3 | 0.1610 | 0.2993 | 0.05562 | 0.1917 | 0.1321 | 0.2617 | 0.1470 | 0.08590 | 0.2007 | 0.2739 | 38.00 |
# | 10 | 3 | 0.2143 | 0.3357 | 0.05315 | 0.2256 | 0.1371 | 0.2498 | 0.2255 | 0.07549 | 0.1805 | 0.3561 | 0.2604 |
# | 25 | 3 | 0.2145 | 0.3336 | 0.05856 | 0.2272 | 0.1341 | 0.2441 | 0.2448 | 0.07507 | 0.1786 | 0.3716 | 0.09064 |
# | 100 | 3 | 0.2185 | 0.3360 | 0.06234 | 0.2152 | 0.1261 | 0.2314 | 0.2804 | 0.06870 | 0.1665 | 0.4125 | 0.02200 |
# | 500 | 3 | 0.2176 | 0.3344 | 0.06547 | 0.2178 | 0.1293 | 0.2331 | 0.2956 | 0.07064 | 0.1682 | 0.4190 | 0.004717 |
# | 1000 | 3 | 0.2162 | 0.3314 | 0.07046 | 0.2137 | 0.1286 | 0.2311 | 0.3082 | 0.06851 | 0.1637 | 0.4349 | 0.002713 |
# | 2000 | 3 | 0.2207 | 0.3397 | 0.06343 | 0.2167 | 0.1267 | 0.2307 | 0.3131 | 0.06952 | 0.1670 | 0.4339 | 0.001854 |
# | 4000 | 3 | 0.2123 | 0.3281 | 0.07002 | 0.2112 | 0.1234 | 0.2248 | 0.3231 | 0.06701 | 0.1611 | 0.4423 | 0.001366 |
# | 10000 | 3 | 0.2160 | 0.3326 | 0.06737 | 0.2151 | 0.1264 | 0.2298 | 0.3100 | 0.06931 | 0.1654 | 0.4349 | 0.001094 |

# %%
gs_crocomse = [0.08590, 0.07549, 0.07507, 0.06870, 0.07064, 0.06851, 0.06952, 0.06701, 0.06931]

# %% [markdown]
# ## Fashion DPR
#
# | steps | lr | reg | MSE | MAE | SSIM | SHRP | PhCo-MSE | PhCo-MAE | PhCo-SSIM | CroCo-MSE | CroCo-MAE | CroCo-SSIM | MSE Magn |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 1 | 0.1 | - | 0.1045 | 0.2072 | 0.2205 | 0.1759 | 0.1214 | 0.2315 | 0.2250 | 0.08373 | 0.1812 | 0.3220 | 36.89 |
# | 10 | 0.1 | - | 0.08590 | 0.1699 | 0.3182 | 0.1730 | 0.09648 | 0.1854 | 0.3364 | 0.05725 | 0.1351 | 0.4468 | 14.93 |
# | 25 | 0.1 | - | 0.07759 | 0.1535 | 0.3792 | 0.1639 | 0.07906 | 0.1574 | 0.4194 | 0.04506 | 0.1139 | 0.5302 | 8.477 |
# | 100 | 0.1 | - | 0.06789 | 0.1389 | 0.4350 | 0.1496 | 0.05839 | 0.1279 | 0.5199 | 0.03382 | 0.09618 | 0.6032 | 3.859 |
# | 500 | 0.1 | - | 0.06180 | 0.1296 | 0.4733 | 0.1422 | 0.05201 | 0.1183 | 0.5639 | 0.02970 | 0.08888 | 0.6387 | 2.352 |
# | 1000 | 0.1 | - | 0.06327 | 0.1307 | 0.4686 | 0.1406 | 0.04494 | 0.1089 | 0.5862 | 0.02862 | 0.08682 | 0.6507 | 2.011 |
# | 2000 | 0.1 | - | 0.06334 | 0.1308 | 0.4722 | 0.1427 | 0.05124 | 0.1159 | 0.5748 | 0.02867 | 0.08697 | 0.6496 | 1.826 |
# | 4000 | 0.1 | - | 0.06111 | 0.1275 | 0.4844 | 0.1405 | 0.04605 | 0.1091 | 0.5914 | 0.02769 | 0.08485 | 0.6602 | 1.707 |
# | 10000 | 0.1 | - | 0.06129 | 0.1284 | 0.4763 | 0.1429 | 0.04630 | 0.1100 | 0.5882 | 0.02869 | 0.08671 | 0.6541 | 1.607 |

# %%
vaeopt_crocomse = [0.08373, 0.05725, 0.04506, 0.03382, 0.02970, 0.02862, 0.02867, 0.02769, 0.02869]

# %% [markdown]
# ### Fashion PRCGAN*
#
# | steps | lr | reg | MSE | MAE | SSIM | SHRP | PhCo-MSE | PhCo-MAE | PhCo-SSIM | CroCo-MSE | CroCo-MAE | CroCo-SSIM | MSE Magn |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 1 | 0.1 | - | 0.01665 | 0.05799 | 0.7702 | 0.1082 | 0.01502 | 0.05613 | 0.7825 | 0.01321 | 0.05307 | 0.7959 | 2.555 |
# | 10 | 0.1 | - | 0.01511 | 0.05340 | 0.7937 | 0.09827 | 0.01245 | 0.04978 | 0.8147 | 0.01058 | 0.04682 | 0.8276 | 1.331 |
# | 25 | 0.1 | - | 0.01454 | 0.05160 | 0.8031 | 0.09432 | 0.01146 | 0.04703 | 0.8299 | 0.009711 | 0.04440 | 0.8405 | 0.9042 |
# | 100 | 0.1 | - | 0.01421 | 0.05022 | 0.8111 | 0.09044 | 0.01026 | 0.04425 | 0.8438 | 0.008930 | 0.04220 | 0.8526 | 0.4784 |
# | 500 | 0.1 | - | 0.01432 | 0.05006 | 0.8121 | 0.08856 | 0.009802 | 0.04305 | 0.8486 | 0.008640 | 0.04126 | 0.8576 | 0.2423 |
# | 1000 | 0.1 | - | 0.01440 | 0.05012 | 0.8118 | 0.08823 | 0.009660 | 0.04276 | 0.8500 | 0.008594 | 0.04110 | 0.8584 | 0.1856 |
# | 2000 | 0.1 | - | 0.01447 | 0.05023 | 0.8111 | 0.08797 | 0.01012 | 0.04327 | 0.8499 | 0.008552 | 0.04102 | 0.8586 | 0.1464 |
# | 4000 | 0.1 | - | 0.01453 | 0.05035 | 0.8104 | 0.08775 | 0.01004 | 0.04322 | 0.8504 | 0.008530 | 0.04099 | 0.8585 | 0.1145 |
# | 10000 | 1.0 | - | 0.01461 | 0.05056 | 0.8093 | 0.08774 | 0.01015 | 0.04343 | 0.8492 | 0.008536 | 0.04106 | 0.8581 | 0.08345 |

# %%
cganopt_crocomse = [0.01321, 0.01058, 0.009711, 0.008930, 0.008640, 0.008594, 0.008552, 0.008530, 0.008536]

# %%
axes = plt.gca()
axes.set_xlabel("Steps k")
axes.set_xscale('log')
axes.set_ylabel("MSE (registered)")
axes.set_ylim([0, 0.12])
plt.title("")
plt.plot(steps, hio_crocomse, marker='.', label="HIO", color='C0')
plt.plot(steps, gs_crocomse, marker='.', label="GS", color='C4')
plt.plot(steps, vaeopt_crocomse, marker='.', label="DPR", color='C2')
plt.plot(steps, cganopt_crocomse, marker='.', label="PRCGAN* (ours)", color='C3')
plt.legend()
plt.grid()
plt.savefig("out/plots/Fashion_iterations.png", dpi=200)
plt.show()
